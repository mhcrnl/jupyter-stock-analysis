# %%
# Install yfinance for the first time
# !conda install -c ranaroussi yfinance --yes
# Out:
# Collecting package metadata (current_repodata.json): ...working... done
# Solving environment: ...working... failed with initial frozen solve. Retrying with flexible solve.
# Collecting package metadata (repodata.json): ...working... done
# Solving environment: ...working... failed with initial frozen solve. Retrying with flexible solve.
# PackagesNotFoundError: The following packages are not available from current channels:
#
#   - yfinance
#
# Current channels:
#
#   - https://conda.anaconda.org/ranaroussi/win-64
#   - https://conda.anaconda.org/ranaroussi/noarch
#   - https://repo.anaconda.com/pkgs/main/win-64
#   - https://repo.anaconda.com/pkgs/main/noarch
#   - https://repo.anaconda.com/pkgs/r/win-64
#   - https://repo.anaconda.com/pkgs/r/noarch
#   - https://repo.anaconda.com/pkgs/msys2/win-64
#   - https://repo.anaconda.com/pkgs/msys2/noarch
#
# To search for alternate channels that may provide the conda package you're
# looking for, navigate to
#
#     https://anaconda.org
#
# and use the search bar at the top of the page.

# %%
import yfinance as yf
import pandas as pd
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 import yfinance as yf
#       2 import pandas as pd
#
# ModuleNotFoundError: No module named 'yfinance'

# %%
data = yf.Ticker('9988.HK')
df = data.history(period="max",interval="1d")

# %%
df['%return'] = df['Close'].pct_change(periods=180)*100

# %%
df.describe()
# Out:
#              Open        High         Low       Close        Volume  \
# count  334.000000  334.000000  334.000000  334.000000  3.340000e+02
# mean   231.857485  234.399701  229.062874  231.867365  2.638125e+07
# std     31.537814   31.786223   31.061586   31.404447  1.531216e+07
# min    172.500000  175.000000  167.600000  170.000000  0.000000e+00
# 25%    206.250000  207.900000  204.200000  206.300000  1.700946e+07
# 50%    225.800000  229.200000  222.100000  225.500000  2.314499e+07
# 75%    256.000000  258.750000  252.550000  257.000000  3.122774e+07
# max    304.400000  309.400000  304.200000  307.400000  1.166863e+08
#
#        Dividends  Stock Splits     %return
# count      334.0         334.0  154.000000
# mean         0.0           0.0   26.032179
# std          0.0           0.0   14.008913
# min          0.0           0.0  -15.290520
# 25%          0.0           0.0   17.963873
# 50%          0.0           0.0   29.041969
# 75%          0.0           0.0   35.558248
# max          0.0           0.0   50.751445

# %%
mean = df.describe()['%return']['mean']
sd = df.describe()['%return']['std']

sharp_ratio = mean/sd
print(f"Sharp Ratio: {sharp_ratio}")
# Out:
# Sharp Ratio: 1.8582582513932626

# %%
import matplotlib.pyplot as plt

fig, (ax1, ax2, ax3) = plt.subplots(3, 1)
# make a little extra space between the subplots
fig.subplots_adjust(hspace=0.5)

fig.set_figheight(12)
fig.set_figwidth(10)


ax1.plot(df.index,df['Close'],color='teal')
ax1.set_title("Historical Price")
ax1.set_xlabel("Date")
ax1.set_ylabel("Close Price")

ax2.bar(df.index,df['Volume'],color='tab:cyan')
ax2.set_title("Historical Volume")
ax2.set_xlabel("Date")
ax2.set_ylabel("Volume")

ax3.bar(df.index,df['%return'],color='orange')
ax3.set_title("Historical %return")
ax3.set_xlabel("Date")
ax3.set_ylabel("%return")

plt.show()

# %%
# !pip install --upgrade mplfinance

# %%
import mplfinance as mpf

mc = mpf.make_marketcolors(up='teal',down='orange',
                           edge='i',
                           wick='i',
                           volume='i',
                           ohlc='i')

s  = mpf.make_mpf_style(marketcolors=mc,facecolor='#fdfdfd',edgecolor='grey',gridaxis='horizontal',gridstyle='dotted')

mpf.plot(df, type='candle',volume=True, style=s)
