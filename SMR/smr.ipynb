# %% [markdown]
# ## NuScale Power Corporation (SMR)
# ### Site: https://www.nuscalepower.com/en
#
# As the global leader in small modular reactor technology, we're bringing clean, affordable nuclear power to all humankind.
#
# Resurse:
# https://www.youtube.com/watch?v=7wAQCwdvqqo

# %%
from pandas_datareader import data as pdr
import yfinance as yf
yf.pdr_override()

import pandas as pd
import matplotlib.pyplot as plt
import mplfinance as mpl

import datetime as dt
import time
import calendar

import pandas as pd
from pandas import DataFrame
import pandas_datareader.data as web
#import pandas.plotting
from pandas.plotting import register_matplotlib_converters
#import pandas.testing
from pandas.testing import assert_frame_equal
import numpy as np

# %%
import webbrowser

url = "https://www.nuscalepower.com/en"  # Replace with the desired URL

# Open the web browser with the URL
webbrowser.open(url)
# Out:
# True

# %%
simbol = 'SBSW'
start_date = dt.datetime(2023,1,1)
end_date = dt.datetime.today()

# %%
def afiseaza_grafic_anul_curent(simbol, start_date, end_date):
    data = web.get_data_yahoo(simbol, start_date, end_date)
    print(data.tail(7))
    mpl.plot(data, type='candle')
    
afiseaza_grafic_anul_curent(simbol, start_date, end_date)
# Out:
# [*********************100%***********************]  1 of 1 completed
#             Open  High   Low  Close  Adj Close   Volume
# Date
# 2023-06-21  6.80  6.81  6.66   6.69       6.69  4884400
# 2023-06-22  6.48  6.62  6.46   6.56       6.56  4154800
# 2023-06-23  6.34  6.45  6.33   6.38       6.38  5171500
# 2023-06-26  6.34  6.42  6.32   6.36       6.36  3193400
# 2023-06-27  6.25  6.27  6.16   6.22       6.22  4620900
# 2023-06-28  6.10  6.16  6.01   6.12       6.12  4181300
# 2023-06-29  6.00  6.27  5.96   6.21       6.21  7368200

# %%
sbsw = yf.Ticker(simbol)
sbsw.info
# Out:
# {'address1': 'Bridgeview House, Building 11',
#  'address2': 'Ground Floor (Lakeview Avenue) Constantia Office Park Cor 14th Ave & Hendrik Potgieter Rd',
#  'city': 'Weltevredenpark',
#  'zip': '1709',
#  'country': 'South Africa',
#  'phone': '27 11 278 9600',
#  'fax': '27 11 278 9863',
#  'website': 'https://www.sibanyestillwater.com',
#  'industry': 'Gold',
#  'industryDisp': 'Gold',
#  'sector': 'Basic Materials',
# ...

# %%
hist = sbsw.history(period='max')
hist
# Out:
#                                Open      High       Low     Close   Volume  \
# Date
# 2013-02-11 00:00:00-05:00  4.177621  4.238362  4.103382  4.218115    92004
# 2013-02-12 00:00:00-05:00  4.353095  4.481326  4.353095  4.481326    17238
# 2013-02-13 00:00:00-05:00  4.488076  4.602809  4.488076  4.569064    75174
# 2013-02-14 00:00:00-05:00  4.893013  5.608406  4.893013  5.041491    41514
# 2013-02-15 00:00:00-05:00  5.014495  5.014495  4.832272  4.926758    18258
# ...                             ...       ...       ...       ...      ...
# 2023-06-23 00:00:00-04:00  6.340000  6.450000  6.330000  6.380000  5171500
# 2023-06-26 00:00:00-04:00  6.340000  6.420000  6.320000  6.360000  3193400
# 2023-06-27 00:00:00-04:00  6.250000  6.270000  6.160000  6.220000  4620900
# 2023-06-28 00:00:00-04:00  6.100000  6.160000  6.010000  6.120000  4181300
# 2023-06-29 00:00:00-04:00  6.000000  6.270000  5.960000  6.210000  7368200
#
#                            Dividends  Stock Splits
# Date
# ...

# %%
# dividends, splits
sbsw.actions
# Out:
#                            Dividends  Stock Splits
# Date
# 2013-10-02 00:00:00-04:00   0.150000          0.00
# 2014-03-12 00:00:00-04:00   0.273529          0.00
# 2014-08-20 00:00:00-04:00   0.183333          0.00
# 2015-03-18 00:00:00-04:00   0.206863          0.00
# 2015-09-02 00:00:00-04:00   0.031373          0.00
# 2016-03-16 00:00:00-04:00   0.230392          0.00
# 2016-09-21 00:00:00-04:00   0.232353          0.00
# 2017-04-05 00:00:00-04:00   0.182353          0.00
# 2017-10-05 00:00:00-04:00   0.000000          1.02
# 2020-09-17 00:00:00-04:00   0.120000          0.00
# 2021-03-18 00:00:00-04:00   0.866000          0.00
# 2021-09-16 00:00:00-04:00   0.807000          0.00
# 2022-03-24 00:00:00-04:00   0.494000          0.00
# 2022-09-15 00:00:00-04:00   0.325000          0.00
# 2023-03-23 00:00:00-04:00   0.268000          0.00

# %%
sbsw.major_holders
# Out:
#        0                                      1
# 0  0.00%        % of Shares Held by All Insider
# 1  8.71%       % of Shares Held by Institutions
# 2  8.71%        % of Float Held by Institutions
# 3    285  Number of Institutions Holding Shares

# %%
sbsw.get_calendar
# Out:
# <bound method TickerBase.get_calendar of yfinance.Ticker object <SBSW>>

# %%
sbsw.get_major_holders
# Out:
# <bound method TickerBase.get_major_holders of yfinance.Ticker object <SBSW>>

# %%
sbsw.institutional_holders
# Out:
#                            Holder   Shares Date Reported   % Out     Value
# 0    Dimensional Fund Advisors LP  4504344    2023-03-30  0.0064  27971976
# 1          Condire Management, LP  3790555    2023-03-30  0.0054  23539346
# 2     AQR Capital Management, LLC  3663239    2023-03-30  0.0052  22748714
# 3  Van Eck Associates Corporation  3127639    2023-03-30  0.0044  19422638
# 4                    Invesco Ltd.  2925820    2023-03-30  0.0041  18169342
# 5            Citadel Advisors Llc  2847091    2023-03-30  0.0040  17680435
# 6               Marshall Wace LLP  2366072    2023-03-30  0.0033  14693307
# 7         Goldman Sachs Group Inc  2195613    2023-03-30  0.0031  13634756
# 8                  Morgan Stanley  2134120    2023-03-30  0.0030  13252885
# 9      Ameriprise Financial, Inc.  1883643    2023-03-30  0.0027  11697423

# %%
sbsw.cashflow
# Out:
#                                                    2022-12-31     2021-12-31  \
# Free Cash Flow                                   -356000000.0  19516000000.0
# Repurchase Of Capital Stock                               0.0  -8503000000.0
# Repayment Of Debt                               -8134000000.0 -20364000000.0
# Issuance Of Debt                                 8000000000.0  20651000000.0
# Issuance Of Capital Stock                                 NaN            0.0
# Capital Expenditure                            -15899000000.0 -12740000000.0
# End Cash Position                               26076000000.0  30292000000.0
# Beginning Cash Position                         30292000000.0  20240000000.0
# Effect Of Exchange Rate Changes                  1112000000.0    708000000.0
# Changes In Cash                                 -5328000000.0   9344000000.0
# Financing Cash Flow                             -3497000000.0  -8344000000.0
# ...

# %%
sbsw.get_news
# Out:
# <bound method TickerBase.get_news of yfinance.Ticker object <SBSW>>

# %%
sbsw.trend_details
# Out:
# ---------------------------------------------------------------------------
# YFNotImplementedError                     Traceback (most recent call last)
# Cell In[18], line 1
# ----> 1 sbsw.trend_details
#
# File ~\anaconda3\lib\site-packages\yfinance\ticker.py:240, in Ticker.trend_details(self)
#     238 @property
#     239 def trend_details(self) -> _pd.DataFrame:
# --> 240     return self.get_trend_details()
#
# File ~\anaconda3\lib\site-packages\yfinance\base.py:1552, in TickerBase.get_trend_details(self, proxy, as_dict)
#    1550 def get_trend_details(self, proxy=None, as_dict=False):
#    1551     self._analysis.proxy = proxy
# -> 1552     data = self._analysis.analyst_trend_details
#    1553     if as_dict:
#    1554         return data.to_dict()
#
# File ~\anaconda3\lib\site-packages\yfinance\scrapers\analysis.py:30, in Analysis.analyst_trend_details(self)
#      27 @property
#      28 def analyst_trend_details(self) -> pd.DataFrame:
# ...

# %%
sbsw.recommendations
# Out:
# ---------------------------------------------------------------------------
# YFNotImplementedError                     Traceback (most recent call last)
# Cell In[19], line 1
# ----> 1 sbsw.recommendations
#
# File ~\anaconda3\lib\site-packages\yfinance\ticker.py:146, in Ticker.recommendations(self)
#     144 @property
#     145 def recommendations(self):
# --> 146     return self.get_recommendations()
#
# File ~\anaconda3\lib\site-packages\yfinance\base.py:1464, in TickerBase.get_recommendations(self, proxy, as_dict)
#    1462 def get_recommendations(self, proxy=None, as_dict=False):
#    1463     self._quote.proxy = proxy
# -> 1464     data = self._quote.recommendations
#    1465     if as_dict:
#    1466         return data.to_dict()
#
# File ~\anaconda3\lib\site-packages\yfinance\scrapers\quote.py:577, in Quote.recommendations(self)
#     574 @property
#     575 def recommendations(self) -> pd.DataFrame:
#     576     if self._recommendations is None:
# ...

# %%
sbsw.isin
# Out:
# 'US82575P1075'

# %%
hist.plot(kind='line', figsize=(12,12), subplots=True)
# Out:
# array([<Axes: xlabel='Date'>, <Axes: xlabel='Date'>,
#        <Axes: xlabel='Date'>, <Axes: xlabel='Date'>,
#        <Axes: xlabel='Date'>, <Axes: xlabel='Date'>,
#        <Axes: xlabel='Date'>], dtype=object)

# %% [markdown]
# ## Adv. Financial Data

# %%
# Major indices
major_indices = pd.read_html("https://finance.yahoo.com/world-indices/")[0]
major_indices.head()
# Out:
# ---------------------------------------------------------------------------
# HTTPError                                 Traceback (most recent call last)
# Cell In[29], line 2
#       1 # Major indices
# ----> 2 major_indices = pd.read_html("https://finance.yahoo.com/world-indices/")[0]
#       3 major_indices.head()
#
# File ~\anaconda3\lib\site-packages\pandas\util\_decorators.py:331, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     325 if len(args) > num_allow_args:
#     326     warnings.warn(
#     327         msg.format(arguments=_format_argument_list(allow_args)),
#     328         FutureWarning,
#     329         stacklevel=find_stack_level(),
#     330     )
# --> 331 return func(*args, **kwargs)
#
# ...
