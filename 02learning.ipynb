# %% [markdown]
# # Learning Past
#
# ## Introduction
# Welcome to my learning past notebook! This notebook will serve as a record of my past learning experiences and achievements.
#
# ## Table of Contents
# 1. [Programming Languages](#programming-languages)
# 2. [Data Analysis](#data-analysis)
# 3. [Machine Learning](#machine-learning)
#
# ## 1. Programming Languages <a id="programming-languages"></a>
# - Python
#   - Basic syntax and control flow
#   - Data structures: lists, dictionaries, tuples
#   - Functions and modules
#   - Object-oriented programming
#
# - JavaScript
#   - DOM manipulation
#   - Asynchronous programming with Promises
#   - Basic web development concepts
#
# ## 2. Data Analysis <a id="data-analysis"></a>
# - Pandas
#   - Data manipulation with DataFrames
#   - Data cleaning and preprocessing
#   - Data aggregation and summarization
#
# - NumPy
#   - Numerical operations on arrays
#   - Linear algebra operations
#
# - Matplotlib
#   - Data visualization: line plots, bar plots, scatter plots
#
# ## 3. Machine Learning <a id="machine-learning"></a>
# - Scikit-learn
#   - Supervised learning algorithms: regression, classification
#   - Model evaluation and validation
#   - Hyperparameter tuning
#
# - TensorFlow
#   - Building and training neural networks
#   - Deep learning concepts: layers, activations, loss functions
#
# ## Conclusion
# This notebook summarizes my learning journey in various programming languages, data analysis, and machine learning. It serves as a reference for my past achievements and a roadmap for future learning endeavors.
#
# Feel free to explore the sections and refer back to this notebook whenever needed. Happy learning!

# %% [markdown]
# Machine Learning in Jupyter Notebook
# Introduction to Machine Learning
# What is machine learning?
# Types of machine learning: supervised, unsupervised, reinforcement learning
# Machine learning workflow
# Overview of popular machine learning algorithms
# Setting up the Environment
# Installation of necessary libraries: scikit-learn, pandas, numpy, matplotlib
# Loading and exploring the dataset
# Data Preprocessing
# Handling missing values
# Encoding categorical variables
# Feature scaling
# Splitting the dataset into training and testing sets
# Supervised Learning Algorithms
# Linear Regression
#
# Introduction to linear regression
# Model training and evaluation
# Handling multiple input features
# Polynomial regression
# Logistic Regression
#
# Introduction to logistic regression
# Model training and evaluation
# Decision boundaries and probability estimation
# Decision Trees and Random Forests
#
# Introduction to decision trees
# Decision tree visualization
# Ensembles and random forests
# Hyperparameter tuning
# Support Vector Machines (SVM)
#
# Introduction to SVM
# Linear SVM and kernel methods
# Soft margin SVM and regularization
# Naive Bayes Classifier
#
# Introduction to Naive Bayes
# Probability theory and Bayes' theorem
# Text classification with Naive Bayes
# Unsupervised Learning Algorithms
# K-Means Clustering
#
# Introduction to clustering
# K-Means algorithm
# Evaluating clustering results
# Hierarchical Clustering
#
# Introduction to hierarchical clustering
# Agglomerative and divisive clustering
# Dendrogram visualization
# Principal Component Analysis (PCA)
#
# Introduction to dimensionality reduction
# PCA algorithm
# Visualizing high-dimensional data with PCA
# Model Evaluation and Selection
# Evaluation metrics for regression: MSE, RMSE, MAE, R-squared
# Evaluation metrics for classification: accuracy, precision, recall, F1-score
# Cross-validation
# Model selection and comparison
# Advanced Topics
# Ensemble methods: bagging, boosting, stacking
# Neural networks and deep learning
# Reinforcement learning basics
# Conclusion
# This course provides an introduction to machine learning in Jupyter Notebook. By following along with the code examples and exercises, you will gain hands-on experience with popular machine learning algorithms and techniques. The course aims to equip you with the knowledge and skills necessary to start applying machine learning in your own projects.
#
# Feel free to customize this outline based on the specific topics and depth of coverage you intend to include in your machine learning course.

# %% [markdown]
# # Introduction to Machine Learning
#
# ## What is Machine Learning?
# Machine learning is a field of artificial intelligence that focuses on developing algorithms and models that enable computers to learn and make predictions or decisions without being explicitly programmed. It involves extracting patterns and insights from data to train models that can generalize and make predictions on unseen data.
#
# ## Supervised Learning
# Supervised learning is a type of machine learning where the model learns from labeled training data. The model is trained on input-output pairs, and its goal is to learn a mapping function that can predict the output for new inputs.
#
# Common supervised learning algorithms include:
# - Linear Regression
# - Logistic Regression
# - Decision Trees
# - Random Forests
# - Support Vector Machines (SVM)
# - Neural Networks
#
# ## Unsupervised Learning
# Unsupervised learning is a type of machine learning where the model learns from unlabeled data. The model's objective is to discover patterns, relationships, or structures within the data.
#
# Common unsupervised learning algorithms include:
# - Clustering algorithms (e.g., K-means, Hierarchical clustering)
# - Dimensionality reduction algorithms (e.g., Principal Component Analysis (PCA), t-SNE)
# - Association rule learning (e.g., Apriori algorithm)
#
# ## Evaluation Metrics
# Evaluation metrics are used to assess the performance of machine learning models. The choice of evaluation metric depends on the specific problem and the type of learning algorithm.
#
# Common evaluation metrics for classification problems:
# - Accuracy
# - Precision
# - Recall
# - F1-score
# - Area Under the ROC Curve (AUC-ROC)
#
# Common evaluation metrics for regression problems:
# - Mean Squared Error (MSE)
# - Root Mean Squared Error (RMSE)
# - Mean Absolute Error (MAE)
# - R-squared (coefficient of determination)
#
# ## Model Training and Evaluation Workflow
# 1. Data Preparation:
#    - Preprocess and clean the data.
#    - Split the data into training and testing sets.
#
# 2. Model Training:
#    - Select an appropriate machine learning algorithm.
#    - Train the model using the training data.
#
# 3. Model Evaluation:
#    - Evaluate the model's performance on the testing data.
#    - Use evaluation metrics to assess the model's accuracy and reliability.
#
# 4. Model Tuning:
#    - Optimize the model's hyperparameters to improve performance.
#    - Use techniques like cross-validation and grid search.
#
# 5. Model Deployment:
#    - Deploy the trained model to make predictions on new, unseen data.
#
# Machine learning is a vast field with many algorithms, techniques, and applications. This notebook provides a brief introduction to some fundamental concepts. Further exploration and hands-on practice will help deepen your understanding and proficiency in machine learning.
#
# Happy learning!

# %%
# Linear Regression in Jupyter Notebook

import numpy as np
import matplotlib.pyplot as plt
from sklearn.linear_model import LinearRegression

# Generate some random data for demonstration
np.random.seed(0)
X = np.random.rand(100, 1) * 10
y = 2 * X + np.random.randn(100, 1)

# Create a linear regression model
model = LinearRegression()

# Fit the model to the data
model.fit(X, y)

# Predict on new data
X_new = np.array([[5]])  # Example: Predicting the target value for a new input feature of 5
y_pred = model.predict(X_new)

# Visualize the data and the linear regression line
plt.scatter(X, y, color='blue', label='Actual Data')
plt.plot(X, model.predict(X), color='red', linewidth=2, label='Linear Regression')
plt.scatter(X_new, y_pred, color='green', label='Predicted Value')
plt.xlabel('X')
plt.ylabel('y')
plt.title('Linear Regression')
plt.legend()
plt.show()
