# %% [markdown]
# ## ETL.PA

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

import pandas_datareader.data as web
import datetime
import yfinance as yf
#yf.pdr_override()
import mplfinance as mpf

# %%
start_date = datetime.datetime(2024,1,1)
end_date = datetime.datetime.today()

# %%
# download dataframe
data = yf.download("ETL.PA", start_date, end_date)
# Out:
# [*********************100%***********************]  1 of 1 completed

# %%
data.index.name = "Data"
data.shape
#data.tail(5)
data.head(5)
# Out:
# Price       Close   High    Low   Open  Volume
# Ticker     ETL.PA ETL.PA ETL.PA ETL.PA  ETL.PA
# Data
# 2024-01-02  4.392  4.392  4.250  4.250  320336
# 2024-01-03  4.320  4.520  4.258  4.492  556823
# 2024-01-04  4.296  4.336  4.210  4.300  287339
# 2024-01-05  4.294  4.306  4.170  4.260  170714
# 2024-01-08  4.268  4.300  4.170  4.270  210811

# %%
data.tail(5)
# Out:
# Price       Close   High    Low   Open  Volume
# Ticker     ETL.PA ETL.PA ETL.PA ETL.PA  ETL.PA
# Data
# 2025-01-14  2.100  2.118  2.000  2.020  354378
# 2025-01-15  2.094  2.154  2.074  2.112  312942
# 2025-01-16  2.100  2.160  2.050  2.100  275227
# 2025-01-17  2.152  2.192  2.070  2.094  217689
# 2025-01-20  2.178  2.178  2.152  2.152    4923

# %%
plt.plot(data)
plt.show()

# %%
mpl.plot(data, type="candle")

# %%
mpl.plot(data, type="line")

# %%
mpl.plot(data, hlines=[5.85, 7.20], type= 'line')

# %%
mpl.plot(data, type="renko")

# %%
mpl.plot(data, type="pnf")

# %%
etlpa = yf.Ticker("SBSW")
# get all stock info
etlpa.info
# Out:
# {'address1': 'Bridgeview House, Building 11',
#  'address2': 'Ground Floor (Lakeview Avenue) Constantia Office Park Cor 14th Ave & Hendrik Potgieter Rd',
#  'city': 'Weltevredenpark',
#  'zip': '1709',
#  'country': 'South Africa',
#  'phone': '27 11 278 9600',
#  'fax': '27 11 278 9863',
#  'website': 'https://www.sibanyestillwater.com',
#  'industry': 'Gold',
#  'industryDisp': 'Gold',
#  'sector': 'Basic Materials',
# ...

# %%
import mplfinance as mpl
mpl.plot(etlpa)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[10], line 2
#       1 import mplfinance as mpl
# ----> 2 mpl.plot(etlpa)
#
# File ~\anaconda3\lib\site-packages\mplfinance\plotting.py:417, in plot(data, **kwargs)
#     414 # translate alias types:
#     415 config['type'] = _get_valid_plot_types(config['type'])
# --> 417 dates,opens,highs,lows,closes,volumes = _check_and_prepare_data(data, config)
#     419 config['xlim'] = _check_and_convert_xlim_configuration(data, config)
#     421 if config['type'] in VALID_PMOVE_TYPES and config['addplot'] is not None:
#
# File ~\anaconda3\lib\site-packages\mplfinance\_arg_validators.py:28, in _check_and_prepare_data(data, config)
#      11 '''
#      12 Check and Prepare the data input:
#      13 For now, data must be a Pandas DataFrame with a DatetimeIndex
#    (...)
# ...

# %%
etlpa = web.DataReader('ETL.PA', 'yahoo', start_date, end_date)
etlpa.head(5)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[9], line 1
# ----> 1 etlpa = web.DataReader('ETL.PA', 'yahoo', start_date, end_date)
#       2 etlpa.head(5)
#
# File ~\anaconda3\lib\site-packages\pandas\util\_decorators.py:211, in deprecate_kwarg.<locals>._deprecate_kwarg.<locals>.wrapper(*args, **kwargs)
#     209     else:
#     210         kwargs[new_arg_name] = new_arg_value
# --> 211 return func(*args, **kwargs)
#
# File ~\anaconda3\lib\site-packages\pandas_datareader\data.py:379, in DataReader(name, data_source, start, end, retry_count, pause, session, api_key)
#     367     raise NotImplementedError(msg)
#     369 if data_source == "yahoo":
#     370     return YahooDailyReader(
#     371         symbols=name,
#     372         start=start,
#     373         end=end,
#     374         adjust_price=False,
#     375         chunksize=25,
# ...
