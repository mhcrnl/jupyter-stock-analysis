# %%
from pandas_datareader import data as pdr
import yfinance as yf
yf.pdr_override()

import pandas as pd
import matplotlib.pyplot as plt
import mplfinance as mpl

import datetime as dt
import time
import calendar

import pandas as pd
from pandas import DataFrame
import pandas_datareader.data as web
#import pandas.plotting
from pandas.plotting import register_matplotlib_converters
#import pandas.testing
from pandas.testing import assert_frame_equal
import numpy as np

# %%
simbol = "ES=F"
start = dt.datetime(2023,1,1)
end   = dt.datetime.now()

df = web.get_data_yahoo(simbol, start, end)

print(df.tail(6))
# Out:
# [*********************100%***********************]  1 of 1 completed
#                Open     High      Low    Close  Adj Close   Volume
# Date
# 2023-06-22  4410.00  4427.00  4393.00  4423.75    4423.75  1384002
# 2023-06-23  4425.75  4426.25  4381.50  4389.00    4389.00  1550992
# 2023-06-26  4390.00  4403.00  4368.50  4370.25    4370.25  1622416
# 2023-06-27  4375.75  4424.75  4371.50  4418.75    4418.75  1512256
# 2023-06-28  4414.00  4430.25  4399.25  4417.50    4417.50  1512256
# 2023-06-30  4435.25  4442.25  4433.00  4437.00    4437.00    33555

# %%
mpl.plot(df, type="candle")
