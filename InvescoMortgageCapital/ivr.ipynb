# %%
from pandas_datareader import data as pdr
import yfinance as yf
yf.pdr_override()

import pandas as pd
import matplotlib.pyplot as plt
import mplfinance as mpl

import datetime as dt
import time
import calendar

import pandas as pd
from pandas import DataFrame
import pandas_datareader.data as web
#import pandas.plotting
from pandas.plotting import register_matplotlib_converters
#import pandas.testing
from pandas.testing import assert_frame_equal
import numpy as np

#

simbol = 'IVR'
start_date = dt.datetime(2009,1,1)
end_date = dt.datetime.now()

print(simbol, start_date, end_date)

def afiseaza_grafic_anul_curent(simbol, start_date, end_date):
    data = web.get_data_yahoo(simbol, start_date, end_date)
    print(data.tail(7))
    print(data.head(7))
    mpl.plot(data, type='line')
    
afiseaza_grafic_anul_curent(simbol, start_date, end_date)
# Out:
# IVR 2009-01-01 00:00:00 2023-06-30 16:44:27.101062
# [*********************100%***********************]  1 of 1 completed
#              Open   High      Low   Close  Adj Close   Volume
# Date
# 2023-06-22  11.55  11.57  11.3300  11.370     11.370   737300
# 2023-06-23  11.25  11.30  11.1000  11.100     11.100  1460800
# 2023-06-26  11.12  11.60  11.1100  11.540     11.540   899200
# 2023-06-27  11.60  11.80  11.4600  11.800     11.800   666100
# 2023-06-28  11.85  11.92  11.7100  11.910     11.910   723000
# 2023-06-29  11.91  11.98  11.7800  11.930     11.930  1155600
# 2023-06-30  11.91  11.56  11.4501  11.455     11.455   151316
#                   Open        High         Low       Close  Adj Close  Volume
# Date
# 2009-07-01  194.899994  195.000000  192.500000  195.000000  33.475067    7990
# 2009-07-02  194.300003  198.500000  194.300003  196.199997  33.681065   25610
# 2009-07-06  197.500000  198.500000  195.000000  195.500000  33.560909   13710
# ...

# %%
data.head(9)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[6], line 1
# ----> 1 data.head(9)
#
# NameError: name 'data' is not defined
