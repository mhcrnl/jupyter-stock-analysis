# %%
from pandas_datareader import data as pdr
import yfinance as yf
yf.pdr_override()

import pandas as pd
import matplotlib.pyplot as plt
import mplfinance as mpl

import datetime as dt
import time
import calendar

import pandas as pd
from pandas import DataFrame
import pandas_datareader.data as web
#import pandas.plotting
from pandas.plotting import register_matplotlib_converters
#import pandas.testing
from pandas.testing import assert_frame_equal
import numpy as np

# %%
simbol = '^N100'
start_date = dt.datetime(2023,1,1)
end_date = dt.datetime.now()

simbol, start_date, end_date
# Out:
# ('^N100',
#  datetime.datetime(2023, 1, 1, 0, 0),
#  datetime.datetime(2023, 6, 30, 12, 49, 5, 168625))

# %%
def afiseaza_grafic_anul_curent(simbol, start_date, end_date):
    data = web.get_data_yahoo(simbol, start_date, end_date)
    print(data.tail(7))
    mpl.plot(data, type='candle')
    
afiseaza_grafic_anul_curent(simbol, start_date, end_date)
# Out:
# [*********************100%***********************]  1 of 1 completed
#                    Open         High          Low        Close    Adj Close  \
# Date
# 2023-06-22  1347.270020  1347.270020  1332.560059  1344.400024  1344.400024
# 2023-06-23  1343.319946  1343.319946  1329.939941  1334.609985  1334.609985
# 2023-06-26  1335.079956  1342.290039  1324.550049  1338.250000  1338.250000
# 2023-06-27  1341.459961  1348.939941  1335.229980  1344.319946  1344.319946
# 2023-06-28  1346.150024  1358.109985  1346.150024  1356.630005  1356.630005
# 2023-06-29  1356.989990  1364.400024  1356.140015  1361.130005  1361.130005
# 2023-06-30  1361.699951  1369.329956  1361.160034  1369.290039  1369.290039
#
#                Volume
# Date
# 2023-06-22  270192900
# 2023-06-23  292558100
# 2023-06-26  249735100
# 2023-06-27  248681800
# 2023-06-28  238364800
# 2023-06-29  277486200
# 2023-06-30          0

# %%
df = pdr.get_data_yahoo(simbol, start_date, end_date)
df
# Out:
# [*********************100%***********************]  1 of 1 completed
#                    Open         High          Low        Close    Adj Close  \
# Date
# 2023-01-02  1232.619995  1252.880005  1232.619995  1252.020020  1252.020020
# 2023-01-03  1251.979980  1272.939941  1251.449951  1257.359985  1257.359985
# 2023-01-04  1257.689941  1279.670044  1257.689941  1279.099976  1279.099976
# 2023-01-05  1278.390015  1281.300049  1272.859985  1275.729980  1275.729980
# 2023-01-06  1275.890015  1294.349976  1275.060059  1294.310059  1294.310059
# ...                 ...          ...          ...          ...          ...
# 2023-06-26  1335.079956  1342.290039  1324.550049  1338.250000  1338.250000
# 2023-06-27  1341.459961  1348.939941  1335.229980  1344.319946  1344.319946
# 2023-06-28  1346.150024  1358.109985  1346.150024  1356.630005  1356.630005
# 2023-06-29  1356.989990  1364.400024  1356.140015  1361.130005  1361.130005
# 2023-06-30  1361.699951  1369.329956  1361.160034  1369.290039  1369.290039
#
#                Volume
# Date
# 2023-01-02          0
# 2023-01-03  172781700
# 2023-01-04  217367800
# 2023-01-05  178555500
# 2023-01-06  153096200
# ...               ...
# 2023-06-26  249735100
# 2023-06-27  248681800
# 2023-06-28  238364800
# 2023-06-29  277486200
# 2023-06-30          0
#
# [127 rows x 6 columns]

# %%
#

simbol = 'PRX.AS'
start_date = dt.datetime(2023,1,1)
end_date = dt.datetime.now()

print(simbol, start_date, end_date)

def afiseaza_grafic_anul_curent(simbol, start_date, end_date):
    data = web.get_data_yahoo(simbol, start_date, end_date)
    print(data.tail(7))
    mpl.plot(data, type='candle')
    
afiseaza_grafic_anul_curent(simbol, start_date, end_date)
# Out:
# PRX.AS 2023-01-01 00:00:00 2023-06-30 12:53:33.303867
# [*********************100%***********************]  1 of 1 completed
#                  Open       High        Low      Close  Adj Close   Volume
# Date
# 2023-06-21  65.150002  65.650002  64.629997  64.699997  64.699997  1187131
# 2023-06-22  64.260002  64.400002  63.500000  64.269997  64.269997  1039470
# 2023-06-23  64.150002  64.989998  62.610001  62.889999  62.889999  1384185
# 2023-06-26  62.889999  63.900002  62.570000  63.250000  63.250000  1370082
# 2023-06-27  66.980003  69.559998  66.339996  67.190002  67.190002  2855529
# 2023-06-28  67.309998  68.089996  66.080002  67.209999  67.209999  1845611
# 2023-06-30  66.160004  66.430000  65.699997  66.099998  66.099998   249826

# %%
# Teleperformance.Se  (TEP.PA)

simbol = 'TEP.PA'
start_date = dt.datetime(2023,1,1)
end_date = dt.datetime.now()

print(simbol, start_date, end_date)

def afiseaza_grafic_anul_curent(simbol, start_date, end_date):
    data = web.get_data_yahoo(simbol, start_date, end_date)
    print(data.tail(7))
    mpl.plot(data, type='candle')
    
afiseaza_grafic_anul_curent(simbol, start_date, end_date)
# Out:
# TEP.PA 2023-01-01 00:00:00 2023-06-30 12:55:34.085639
# [*********************100%***********************]  1 of 1 completed
#                   Open        High         Low       Close   Adj Close  Volume
# Date
# 2023-06-20  159.500000  160.250000  157.750000  158.000000  158.000000  224399
# 2023-06-21  157.750000  157.750000  155.250000  155.449997  155.449997  213273
# 2023-06-22  153.100006  154.899994  151.149994  151.800003  151.800003  299030
# 2023-06-23  151.300003  155.250000  150.949997  153.149994  153.149994  242830
# 2023-06-26  153.500000  153.600006  150.149994  150.949997  150.949997  140281
# 2023-06-27  151.449997  151.899994  147.300003  148.649994  148.649994  209381
# 2023-06-30  154.750000  155.649994  153.550003  154.050003  154.050003   26153

# %%
# Sanofi

simbol = 'SAN.PA'
start_date = dt.datetime(2023,1,1)
end_date = dt.datetime.now()

print(simbol, start_date, end_date)

def afiseaza_grafic_anul_curent(simbol, start_date, end_date):
    data = web.get_data_yahoo(simbol, start_date, end_date)
    print(data.tail(7))
    mpl.plot(data, type='candle')
    
afiseaza_grafic_anul_curent(simbol, start_date, end_date)
# Out:
# SAN.PA 2023-01-01 00:00:00 2023-06-30 12:58:02.328954
# [*********************100%***********************]  1 of 1 completed
#                  Open       High        Low      Close  Adj Close   Volume
# Date
# 2023-06-20  96.400002  98.320000  96.360001  97.970001  97.970001  2432404
# 2023-06-21  97.199997  98.169998  97.000000  98.029999  98.029999  1384221
# 2023-06-22  97.239998  97.889999  96.400002  97.620003  97.620003  1282467
# 2023-06-23  97.620003  99.199997  97.180000  98.599998  98.599998  1868745
# 2023-06-26  97.940002  98.930000  97.250000  97.839996  97.839996  1383095
# 2023-06-27  97.980003  98.320000  96.970001  97.889999  97.889999  1062655
# 2023-06-30  97.620003  98.040001  97.010002  97.970001  97.970001   192113
